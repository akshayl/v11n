# %%
import pandas as pd
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('taxirides.csv')

# %%
df.head(5)
# Out:
#        ID          PICKUP_TIME                                PICKUP_ADDRESS  \
# 0  230216  2012-05-11 00:00:00             317 Washington St Boston Ma 02135
# 1  230217  2012-05-11 00:00:00                        Unnamed Road Boston Ma
# 2  230218  2012-05-11 00:00:00        Beacon St @ Commonwealth Ave Boston Ma
# 3  230219  2012-05-11 00:00:00  Commonwealth Ave @ Beacon St Boston Ma 02215
# 4  230228  2012-05-11 00:00:00               400 Boylston St Boston Ma 02116
#
#    PICKUP_LONG  PICKUP_LAT
# 0   -71.152022   42.349030
# 1   -71.018663   42.369197
# 2   -71.097962   42.348598
# 3   -71.096017   42.348735
# 4   -71.072253   42.351457

# %%
figsize(15, 15)
plt.hexbin(df['PICKUP_LONG'], df['PICKUP_LAT'], bins='log', gridsize=500, cmap=plt.cm.CMRmap, axes=None)
