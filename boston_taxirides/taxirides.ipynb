# %%
import pandas as pd
import numpy as np

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('pickups.csv')

# %%
df.head(5)
# Out:
#        ID          PICKUP_TIME                    PICKUP_ADDRESS  PICKUP_LONG  \
# 0  156527  2012-05-07 14:54:00     50 Francis St Boston Ma 02215   -71.107178
# 1  156528  2012-05-07 17:26:00  1080 Boylston St Boston Ma 02215   -71.088070
# 2  156529  2012-05-07 17:26:00     50 Seaport Ln Boston Ma 02210   -71.041327
# 3  156530  2012-05-07 14:55:00              Viaduct St Boston Ma   -71.041705
# 4  156532  2012-05-07 17:27:00   830 Boylston St Boston Ma 02199   -71.082857
#
#    PICKUP_LAT
# 0   42.335685
# 1   42.347138
# 2   42.349207
# 3   42.349905
# 4   42.348595

# %%
figsize(15, 15)
plt.hexbin(df['PICKUP_LONG'], df['PICKUP_LAT'], bins='log', gridsize=2000, cmap=plt.cm.CMRmap, axes=None)
